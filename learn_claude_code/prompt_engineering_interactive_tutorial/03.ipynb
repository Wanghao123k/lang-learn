# %%
from anthropic import Anthropic
from dotenv import load_dotenv
import os

load_dotenv(override=True)
client = Anthropic(base_url=os.getenv("ANTHROPIC_BASE_URL"))
MODEL_NAME = "MiniMax-M2.7"

def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model="MiniMax-M2.7",
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    for block in message.content:
        if block.type == "text":
            return block.text
    return ""

# %%
# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I think skateboarding is an exhilarating blend of creativity, community, and physical challenge that continues to push the boundaries of urban expression.

# %%
# System prompt
SYSTEM_PROMPT = "You are a cat."

# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
# Out:
# Skateboarding is a beautiful blend of creativity, persistence, and urban freedom where rolling and flipping become poetry in motion.
